# %%
pip install nltk scikit-learn
# Out:
# Requirement already satisfied: nltk in c:\users\user\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk) (8.4.2)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk) (2026.7.19)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import random
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# Load dataset
with open('intents.json') as file:
    data = json.load(file)

patterns = []
tags = []

# Prepare data
for intent in data['intents']:
    for pattern in intent['patterns']:
        patterns.append(pattern)
        tags.append(intent['tag'])

# Convert text to numbers
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(patterns)

# Train model
model = LogisticRegression()
model.fit(X, tags)

# Get response
def get_response(tag):
    for intent in data['intents']:
        if intent['tag'] == tag:
            return random.choice(intent['responses'])

# Chat loop
print("Chatbot: Hello! Type 'quit' to exit.")
while True:
    user_input = input("You: ")
    
    if user_input.lower() == "quit":
        print("Chatbot: Goodbye!")
        break

    X_test = vectorizer.transform([user_input])
    tag = model.predict(X_test)[0]
    
    response = get_response(tag)
    print("Chatbot:", response)
# Out:
# Chatbot: Hello! Type 'quit' to exit.
# You:  hi
# Chatbot: Hello, thanks for visiting
# You:  what is your name
# Chatbot: I'm your virtual assistant.
# You:  bye
# Chatbot: Bye! Come back again soon.
# You:  quit
# Chatbot: Goodbye!

# %%
import joblib

joblib.dump(model, 'model.pkl')
joblib.dump(vectorizer, 'vectorizer.pkl')
# Out:
# ['vectorizer.pkl']
